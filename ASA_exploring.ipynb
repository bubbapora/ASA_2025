# %% [markdown]
# <a href="https://colab.research.google.com/github/bubbapora/ASA_2025/blob/main/ASA_exploring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Consumer_Airfare_Report__Table_2_-_Top_1_000_City-Pair_Markets.csv')

# %%
df.head()
# Out:
#        tbl  Year  quarter  citymarketid              city  markets  \
# 0  Table 2  2021        4         34576     Rochester, NY        7
# 1  Table 2  2021        4         33495   New Orleans, LA       30
# 2  Table 2  2021        4         32337  Indianapolis, IN       25
# 3  Table 2  2021        4         33214   San Antonio, TX       30
# 4  Table 2  2021        4         32600   Little Rock, AR        7
#
#    cur_passengers  cur_fare  cur_yield  distance  ly_passengers  ly_fare  \
# 0          170560    162.92      25.13     648.2        42450.0   150.54
# 1         1571520    186.78      18.88     989.5       656740.0   150.32
# 2         1246520    206.51      19.79    1043.7       570540.0   164.68
# 3         1219290    207.84      18.36    1131.7       530200.0   185.53
# 4          126870    191.80      23.06     831.6        68150.0   166.98
#
#    ly_yield  ly_distance Geocoded_City      tbl2pk
# 0     19.47        773.4           NaN  2021434576
# ...
